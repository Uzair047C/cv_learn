# %%
import tensorflow as tf
import cv2
from ultralytics import YOLO
# Out:
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\cuda\__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
model = YOLO("yolov8n.pt")

cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()

    results = model(frame)

    annotated = results[0].plot()

    cv2.imshow("Detection", annotated)

    if cv2.waitKey(1) == ord('q'):
        break
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 3.4MB/s 1.8s.8s<0.0s1.6s9s
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 107.8ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 46.7ms
# Speed: 4.5ms preprocess, 77.2ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 46.9ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.4ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.4ms
# Speed: 1.3ms preprocess, 37.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 46.8ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 37.5ms
# Speed: 1.4ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 42.9ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 42.6ms
# Speed: 1.4ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 48.6ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 38.4ms
# Speed: 2.1ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 42.5ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.6ms
# Speed: 1.3ms preprocess, 38.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.8ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.9ms
# Speed: 1.4ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.5ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.7ms
# Speed: 1.3ms preprocess, 37.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.8ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.1ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 84.6ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.6ms
# Speed: 1.4ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 41.0ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.2ms
# Speed: 1.3ms preprocess, 37.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.3ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.1ms
# Speed: 1.4ms preprocess, 36.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.1ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.9ms
# Speed: 1.5ms preprocess, 36.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.0ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.5ms
# Speed: 1.4ms preprocess, 36.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.0ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.8ms
# Speed: 1.5ms preprocess, 37.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.7ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.0ms
# Speed: 1.4ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.9ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.6ms
# Speed: 1.7ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.3ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 42.6ms
# Speed: 1.4ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.8ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.3ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.5ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 36.9ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.3ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.3ms
# Speed: 1.4ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.4ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.4ms
# Speed: 1.5ms preprocess, 36.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 41.9ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.9ms
# Speed: 1.4ms preprocess, 38.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.2ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.4ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.2ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.2ms
# Speed: 1.6ms preprocess, 37.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.6ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.9ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.3ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.3ms
# Speed: 1.4ms preprocess, 35.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 37.8ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.8ms
# Speed: 1.4ms preprocess, 35.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.5ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.4ms
# Speed: 1.6ms preprocess, 37.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.7ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.2ms
# Speed: 1.6ms preprocess, 36.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.0ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.6ms
# Speed: 1.4ms preprocess, 37.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.1ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.4ms
# Speed: 1.3ms preprocess, 37.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 45.0ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 38.5ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.7ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.4ms
# Speed: 1.4ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 41.7ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.8ms
# Speed: 1.4ms preprocess, 38.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.6ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.7ms
# Speed: 1.4ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.6ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.5ms
# Speed: 1.4ms preprocess, 38.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 41.0ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.2ms
# Speed: 1.3ms preprocess, 37.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.9ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.8ms
# Speed: 1.3ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.1ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.6ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 37.4ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.9ms
# Speed: 1.4ms preprocess, 35.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.6ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.8ms
# Speed: 1.4ms preprocess, 37.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 41.3ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.3ms
# Speed: 1.3ms preprocess, 37.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.7ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.3ms
# Speed: 1.3ms preprocess, 36.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.1ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.5ms
# Speed: 1.7ms preprocess, 37.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.5ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 40.4ms
# Speed: 1.4ms preprocess, 40.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 41.5ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.7ms
# Speed: 1.6ms preprocess, 37.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.3ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.3ms
# Speed: 1.4ms preprocess, 36.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.7ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.6ms
# Speed: 1.1ms preprocess, 37.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.2ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 36.2ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 37.8ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.9ms
# Speed: 1.4ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 48.6ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 36.5ms
# Speed: 12.6ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.2ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 36.2ms
# Speed: 1.3ms preprocess, 37.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.1ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.1ms
# Speed: 1.3ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.4ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.9ms
# Speed: 1.4ms preprocess, 38.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.3ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.3ms
# Speed: 1.4ms preprocess, 37.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 41.5ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.5ms
# Speed: 1.6ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 42.3ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 33.5ms
# Speed: 2.4ms preprocess, 37.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.5ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.8ms
# Speed: 1.4ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.4ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.2ms
# Speed: 1.4ms preprocess, 37.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 39.6ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.0ms
# Speed: 1.4ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.2ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.2ms
# Speed: 1.7ms preprocess, 37.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 38.9ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 36.8ms
# Speed: 1.4ms preprocess, 37.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
#
# image 1/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 40.5ms
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 35.0ms
# Speed: 1.3ms preprocess, 37.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ...
# image 2/2 C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets\zidane.jpg: 384x640 2 persons, 1 tie, 34.1ms
# Speed: 1.5ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# WARNING 'source' is missing. Using 'source=C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\assets'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 9
#       5 while True:
#       7     ret, frame = cap.read()
# ----> 9     results = model(frame)
#      11     annotated = results[0].plot()
#      13     cv2.imshow("Detection", annotated)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)    175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\engine\model.py:537, in Model.predict(self, source, stream, predictor, **kwargs)
#     535 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     536     self.predictor.set_prompts(prompts)
# --> 537 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\engine\predictor.py:228, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     226     return self.stream_inference(source, model, *args, **kwargs)
#     227 else:
# --> 228     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\utils\_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\engine\predictor.py:337, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     335 # Inference
#     336 with profilers[1]:
# --> 337     preds = self.inference(im, *args, **kwargs)
#     338     if self.args.embed:
#     339         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\engine\predictor.py:185, in BasePredictor.inference(self, im, *args, **kwargs)
#     179 """Run inference on a given image using the specified model and arguments."""
#     180 visualize = (
#     181     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     182     if self.args.visualize and (not self.source_type.tensor)
#     183     else False
#     184 )
# --> 185 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\nn\autobackend.py:279, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     276 if self.format == "pt":
#     277     forward_kwargs = {"augment": augment, "visualize": visualize, "embed": embed, **kwargs}
# --> 279 y = self.backend.forward(im, **forward_kwargs)
#     281 if isinstance(y, (list, tuple)):
#     282     if len(self.names) == 999 and (self.task == "segment" or len(y) == 2):  # segments and names not defined
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\nn\backends\pytorch.py:90, in PyTorchBackend.forward(self, im, augment, visualize, embed, **kwargs)
#      75 def forward(
#      76     self, im: torch.Tensor, augment: bool = False, visualize: bool = False, embed: list | None = None, **kwargs: Any
#      77 ) -> torch.Tensor | list[torch.Tensor]:
#      78     """Run native PyTorch inference with support for augmentation, visualization, and embeddings.
#      79
#      80     Args:
#    (...)     88         (torch.Tensor | list[torch.Tensor]): Model predictions as tensor(s).
#      89     """
# ---> 90     return self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\nn\tasks.py:144, in BaseModel.forward(self, x, *args, **kwargs)
#     142 if isinstance(x, dict):  # for cases of training and validating while training.
#     143     return self.loss(x, *args, **kwargs)
# --> 144 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\nn\tasks.py:161, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     159 if augment:
#     160     return self._predict_augment(x)
# --> 161 return self._predict_once(x, profile, visualize, embed)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\nn\tasks.py:183, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     181 if profile:
#     182     self._profile_one_layer(m, x, dt)
# --> 183 x = m(x)  # run
#     184 y.append(x if m.i in self.save else None)  # save output
#     185 if visualize:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\nn\modules\block.py:311, in C2f.forward(self, x)
#     309 """Forward pass through C2f layer."""
#     310 y = list(self.cv1(x).chunk(2, 1))
# --> 311 y.extend(m(y[-1]) for m in self.m)
#     312 return self.cv2(torch.cat(y, 1))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\nn\modules\block.py:311, in <genexpr>(.0)
#     309 """Forward pass through C2f layer."""
#     310 y = list(self.cv1(x).chunk(2, 1))
# --> 311 y.extend(m(y[-1]) for m in self.m)
#     312 return self.cv2(torch.cat(y, 1))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\nn\modules\block.py:481, in Bottleneck.forward(self, x)
#     479 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     480     """Apply bottleneck with optional shortcut connection."""
# --> 481     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ultralytics\nn\modules\conv.py:89, in Conv.forward_fuse(self, x)
#      80 def forward_fuse(self, x):
#      81     """Apply convolution and activation without batch normalization.
#      82
#      83     Args:
#    (...)     87         (torch.Tensor): Output tensor.
#      88     """
# ---> 89     return self.act(self.conv(x))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\conv.py:565, in Conv2d.forward(self, input)
#     564 def forward(self, input: Tensor) -> Tensor:
# --> 565     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\torch\nn\modules\conv.py:560, in Conv2d._conv_forward(self, input, weight, bias)
#     547 if self.padding_mode != "zeros":
#     548     return F.conv2d(
#     549         F.pad(
#     550             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    557         self.groups,
#     558     )
# --> 560 return F.conv2d(
#     561     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     562 )
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
